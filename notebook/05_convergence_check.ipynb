# %%
import json
import numpy as np
import matplotlib.pyplot as plt

agents = ["sarsa", "dqn", "ppo", "qrdqn", "iqn"]

for agent in agents:
    with open(f"logs/{agent}_handcrafted_asymmetric_seed42/train_history.json") as f:
        history = json.load(f)

    rewards  = [ep["final_pnl"]  for ep in history]
    sharpes  = [ep["sharpe"]     for ep in history]
    maps     = [ep["map"]        for ep in history]

    # Check 1: reward trending upward by episode 500
    early = np.mean(rewards[:100])
    late  = np.mean(rewards[500:600])
    print(f"{agent}: early PnL={early:.2f}, ep500 PnL={late:.2f}, trending={'YES' if late > early else 'NO'}")

    # Check 2: inventory at bounds <5% of steps
    # (need per-step inventory — add to run_episode logging if missing)

    # Check 3: plot smoothed reward curve
    smoothed = np.convolve(rewards, np.ones(20)/20, mode='valid')
    plt.plot(smoothed, label=agent)

plt.legend()
plt.xlabel("Episode")
plt.ylabel("PnL (smoothed 20-ep)")
plt.title("Week 6 — Convergence Check")
plt.savefig("experiments/w06_convergence/convergence.png", dpi=150)
